# %% [markdown]
# # Final parquet exported here is what is used for LLM processing
#
# https://colab.research.google.com/drive/1cPGYCw5PHbV7CVzomZi2sdIqOxru2S1i#scrollTo=KXWprHyvLGUp

# %% [markdown]
# ## Filter full dataset to rows that include mention of pension allowance amounts

# %% [markdown]
# ### start with original dataset, filter rows, then apply file categories from grouped data
#
# parsons-major-studio-1-fall-2025/projects/quantitative/data/nara_pension_file_pages.parquet

# %%
import pandas as pd

# %%
import re

# %%
# original dataset
df = pd.read_parquet("../../quantitative/data/nara_pension_file_pages.parquet")
# grouped data with file categories
df_grouped = pd.read_parquet("../../quantitative/data/df_grouped_NAID_sorted_title_categories.parquet")

# %%
# df.head()
# df_grouped.head()

# %%
df_cats = df.merge(
    df_grouped[['NAID', 'file_cat']],  
    on='NAID',
    how='left'
)

# %%
# df_cats.head()
df_cats.shape
# Out:
# (2244629, 20)

# %%
# df_cats['file_cat'].value_counts()

# %%
# filter out rows with file_cat == non_application or nara archival administrative sheets
df_cats_filtered = df_cats[df_cats['file_cat'] != 'non_application']
df_cats_filtered = df_cats_filtered[df_cats_filtered['file_cat'] != 'nara archival administrative sheets']

# %%
# filter out rows with None for ocrText
df_cats_filtered = df_cats_filtered[df_cats_filtered['ocrText'].notna()]

# %%
df_cats_filtered.shape
# Out:
# (2199104, 20)

# %% [markdown]
# ### filter dataset for rows regarding pension amounts

# %%
phrases = [
    'at the rate', 
    "dollars", 
    "$",
    "per month",
    "per annum", 
    "on the roll", 
    "act of",
    "revolutionary claim",
    "certificate of pension",
    "arrears",
    "semi anl",
    "allowance ending",
    "commence on"
]

# %%
# prefer transcriptionText if available, otherwise use ocrText
df_cats_filtered['priority_text'] = df_cats_filtered['transcriptionText'].fillna(df_cats_filtered['ocrText'])

# %%
df_cats_filtered.shape
# Out:
# (2199104, 21)

# %%
# # Create a 10% sample
# sample_size = int(len(df_cats_filtered) * 0.1)
# df_sample = df_cats_filtered.sample(n=sample_size, random_state=42)

# print(f"Sample size: {len(df_sample)}")

# # Case-insensitive approach: Check each phrase individually
# phrase_masks = []
# for phrase in phrases:
#     phrase_mask = df_sample['priority_text'].str.contains(phrase, case=False, na=False)
#     phrase_masks.append(phrase_mask)

# # Sum across all phrase masks (True = 1, False = 0)
# total_matches = sum(phrase_masks)
# mask = total_matches >= 2

# # Apply the mask
# df_sample_filtered = df_sample[mask]

# # Check results
# print(f"Sample rows with 2+ phrases: {mask.sum()}")
# print(f"Sample rows total: {len(df_sample)}")
# print(f"Sample percentage: {mask.sum()/len(df_sample)*100:.2f}%")
# print(f"Expected full dataset matches: {mask.sum() * 10}")
# Out:
# Sample size: 219910
# Sample rows with 2+ phrases: 50029
# Sample rows total: 219910
# Sample percentage: 22.75%
# Expected full dataset matches: 500290

# %%
# Case-insensitive approach for full dataset
print(f"Starting filtering on {len(df_cats_filtered)} rows...")

# Check each phrase individually
phrase_masks = []
for phrase in phrases:
    phrase_mask = df_cats_filtered['priority_text'].str.contains(phrase, case=False, na=False)
    phrase_masks.append(phrase_mask)

# Sum across all phrase masks (True = 1, False = 0)
total_matches = sum(phrase_masks)
mask = total_matches >= 2

# Apply the mask
df_filtered_by_phrase = df_cats_filtered[mask]

# Check results
print(f"Rows with 2+ phrases: {mask.sum()}")
print(f"Total rows: {len(df_cats_filtered)}")
print(f"Percentage: {mask.sum()/len(df_cats_filtered)*100:.2f}%")
# Out:
# Starting filtering on 2199104 rows...
# Rows with 2+ phrases: 497834
# Total rows: 2199104
# Percentage: 22.64%

# %%
# df_filtered_by_phrase

# %%
# Display 15 samples in a more compact format
print("15 samples of ocrText from filtered data:")
print("=" * 80)

samples = df_filtered_by_phrase['ocrText'].tail(15)
for i, text in enumerate(samples):
    print(f"\n[{i+1}] {text}")
# Out:
# 15 samples of ocrText from filtered data:
# ================================================================================
#
# [1] Declaration
# Samuel Carson
# of
# In order to obtain the
# provisions made by a late
# act of Congress entitled "An
# act to provide for certain "
# persons engaged in the
# of
# land and Naval Service,
# of the United States during the
# war of the Revolution
# .
# May 25th 1818
# Application No 1.
# Sefton
# Contents
# vert
#
# [2] State of New York
# Chenango County ss:
# To
# me
# Isaack
# On this Twenty Fifth
# Day of May 1818 before me the Subscribed one of the
# Judges of the Court of Common Pleas in and
# 1
# for the County of Chenango personally appears
# Samuel Carson aged Sixty Nine years resident
# in the Town of Oxford in the County of Chenango
# who being first by me duly sworn according to
# law doth on his make the following declaration
# in order to obtain the provission made by the late
# act of Congress entitled an act to provide for certain
# persons engaged in the land and Naval Service
# of
# of the United States in the revolutionary war.-
# That he the said Samuel Carson enlisted in Rochester
# in the County of Ulster and State of New York
# in a company commanded by Capt Comelins
# Hardenbergh in a Regiment commanded by
# Colonel Richard in the month of March in
# the year 1776, for the Term of Nine month. And
# continued to serve in said corps in the service of the
# United States until about the Twenty Fifth Day
# December 1776 when he was duly discharged from
# Service at Whiteplains in the State of New York.
# That he was in the Battle of white plains in the State of
# New York in the year 1776. And that he is in
# reduced circumstances and stands in need
# of the assistance of his country for support. And
# that he has no other evidence now in his power
# of his said services.
# me to and declared before
# the Day and year aforesaid
# Sherwood one of the Judges, Saml Carson
# of the Court of Common Pleas
# in & for Chenango County
#
# [3] Chenango County
# Isaac Sherwood one of the Judges of the Court
# of Common Pleas in and for the County of Chenango
# Do certify that it appears to my satisfaction at the
# above named Samuel Carter did live on the
# .
# Revolutionary war as stated in the preceding
# Declaration for Nine Months on the Continental
# Establishment against the Common enemy. And also
# that the above named Samuel Carson is in
# reduced circumstances and stands in need
# of the assistance of his country for support. I now
# Transmit the proceedings and testimony taken and
# had before me to the Secretary for the Department
# of war pursuant to the directions of the aforementioned
# act of Congress. In Testimony whereof I have hereunto
# set my hand and caused the Seal of the said
# Court to be hereunto affixed this 25th Day
# of May 1818
# Isaac Sherwood Judge
# Clerks office
# Chenango County
# Certify that the above named
# Sherwood is a judge of the Court of Common
# Pleas in and for Chenango County. And
# that the above signatures are by and in
# the hand writing of him the said Isaac
# Sherwood. In witness whereof I have hereunto
# affixed the Seal of the said Court at the Clerks
# office in the said County this 27th day of May
# in the year 1818
# Michael G Bright Dep clk
# of
# said County
#
# [4] to
# all of New York
# Chenango County
# S
# On the 12th day of February
# widow of James Carson
# who was a pensioner under the Act of March 1818
# and who died on the 18th Sept. 1821
# of Rockland Co. in the State of N. York
# who was a Sergeant in the company commanded
# by Captain Pell
# of the Regt commanded
# by Col. Cortland in the N. York
# line for 2 years
# Inscribed on the Roll of New York
# at the rate of 120 Dollars - Cents per annum,
# to commence on the 4th day of March, 1836.
# Certificate of Pension issued the 13th day of May
# 1839 and sent to David Pye
# Clarkstown, N.Y.
# Arrears to the 4th of March 39
# Semi-annual allowance ending Sep
# Recorded by
# Book A.
# 360.00
# 60.00
# $20.00
# D. Brown
# Vol. 2
# Act July 7,
# 1838.
# Page 72
# Clerk,
#
# [15] S
# li
# before
# State of New York
# Rockland County ⎬
# ss
# On this twenty second day of April 1843
# personally appeared before me Peter S Stephens a Justice of
# the peace in and for said county, Mary Carson, a resident of
# the town of Orange, in said county, aged Seventy four years,
# who, being first duly sworn, according to law, doth, on her oath
# make the following declaration, in order to obtain the benefits
# of the provision made by the act of Congress, passed on the 3d March
# 1843, granting pensions to widows of persons who served during the
# Revolutionary War. That she is the widow of James Carson
# who was a Sergeant and served in the Continental line in
# Colr Courtland Regiment. That the annual amount of the
# pension which she recieved under the act of July 7. 1838, was
# one hundred and twenty dollars.
# she further declares that she is still a widow
# in to and subscribed, on the
# day and year above written ⎬
# her
# Mary Carson
# Peter T Stephens Justice
# mark
# I certify that the declarant is personally known
# to me to be such widow, and further that she is
# illiterate, and unable to write her name
# Peter T Stephens
# Rockly
# Justice of the peace
# &
# -
# and County to
# I, Abraham Hogenkamp Clerk of the County of Rockland, Do
# Certify that Peter I Stephens is a magistrate as above, and that the
# signatures purporting to be his are genuine
# In testimony whereof, I have hereunto set my hand
# and affixed my seal of office, this first day of May 1843
# Ann Hogenhamp Clerk

# %% [markdown]
# example text in different format:
#
# On this twenty second day of April 1843
# personally appeared before me Peter S Stephens a Justice of
# the peace in and for said county, Mary Carson, a resident of
# the town of Orange, in said county, aged Seventy four years,
# who, being first duly sworn, according to law, doth, on her oath
# make the following declaration, in order to obtain the benefits
# of the provision made by the act of Congress, passed on the 3d March
# 1843, granting pensions to widows of persons who served during the
# Revolutionary War. That she is the widow of James Carson
# who was a Sergeant and served in the Continental line in
# Colr Courtland Regiment. That the annual amount of the
# pension which she recieved under the act of July 7. 1838, was
# one hundred and twenty dollars.
# she further declares that she is still a widow
# in to and subscribed, on the
# day and year above written ⎬
# her
# Mary Carson
# Peter T Stephens Justice
# mark
# I certify that the declarant is personally known
# to me to be such widow, and further that she is
# illiterate, and unable to write her name
# Peter T Stephens
# Rockly
# Justice of the peace

# %% [markdown]
# ### Try different filtering - must contain "dollars" and then one of phrases and not contain acres (limit just to pension allowance amounts, not land bounty warrants)

# %%
dollars = ["dollars", "dollar", "$"]

phrases2 = [
    'at the rate', 
    "per month",
    "per annum", 
    "on the roll", 
    "act of",
    "revolutionary claim",
    "certificate of pension",
    "arrears",
    "semi anl",
    "allowance ending",
    "commence on"
]

# %%
# Build safe regex patterns (escape special chars like $)
pattern_dollars = re.compile("|".join(re.escape(s) for s in dollars), re.IGNORECASE)
pattern_phrases2 = re.compile("|".join(re.escape(s) for s in phrases2), re.IGNORECASE)
pattern_acre = re.compile("|".join(re.escape(s) for s in ["acre", "acres"]), re.IGNORECASE)

# Create masks on priority_text
m_dollars = df_cats_filtered['priority_text'].str.contains(pattern_dollars, na=False)
m_phrases2 = df_cats_filtered['priority_text'].str.contains(pattern_phrases2, na=False)
m_no_acre = ~df_cats_filtered['priority_text'].str.contains(pattern_acre, na=False)  # NOT containing acre/acres

# Require: (dollars AND phrases2) AND NOT acre
mask = m_dollars & m_phrases2 & m_no_acre
df_filtered = df_cats_filtered[mask]

# %%
print(f"Rows kept: {mask.sum()} / {len(df_cats_filtered)} ({mask.mean()*100:.2f}%)")

# previous before remove acres: Rows kept: 205956 / 2199104 (9.37%)
# Out:
# Rows kept: 201523 / 2199104 (9.16%)

# %%
print(df_filtered.shape)
print(df_cats_filtered.shape)
# Out:
# (201523, 21)
# (2199104, 21)

# %%
# Display 15 random samples in a more compact format
print("15 random samples of ocrText from filtered data:")
print("=" * 80)

n = min(15, len(df_filtered))
samples = df_filtered.sample(n=n, random_state=42)['ocrText']

for i, text in enumerate(samples, start=1):
    print(f"\n[{i}] {text}")
# Out:
# 15 random samples of ocrText from filtered data:
# ================================================================================
#
# [1] Reported
# N. Reso
# a
# =
# 11004
# =
# Ohio
# Cunice Alilder
# Widow of Reuben W Wilder
# who was a pensioner under the Act of 1818
# and who died on the 26th Sept 1840
# of Ashton in the State of Ohio
# who was a Private in the Compy
# commanded by Captain
# of the
# Regt commanded by
# in
# the Revolution line for 15 mo Private
# Inscribed on the Roll of
# Pittsburgh
# at the rate of 30 Dollars
# Cents per annum, to commence on the 4th day
# of March, 1836
# Certificate of Pension issued the 8th day of
# July
# 1846 and sent to James
# 1
# =
# Miller
# Total amount,
# $250.00
# Act July 7, 1838.}
# Recorded by the Lumpkin
# Clerk,
# Book D Vol. 4 Page 399
#
# [2] Grained 125th
# George Keller
# of Monongalia in the State of Elgin
# who was a Private in the Compy command
# by Captain Tompson of the regt
# commande
# by Col Christie in the Origina
# line for 19 ½ months
# ---
# $65.
# Inscribed on the Roll of Virginia
# at the rate of 60 Dollars 00 Cents per ann
# to commence on the 4th day of March, 1831.
# Certificate of Pension issued the 10 day of May
# and sent to J. P. Ray
# Morgantown, M. C.
# Arrears to the 4th of March 33
# 130.
# Semi-anl. allowance ending 4 Sept.
# 1836.
# 32
# ---
# $1623
# ---
# -
# Recorded by
# Book C
# Revolutionary Claim,
# Act June 7, 1832.
# Wm
# Palmer
# Vol.
# Page 85
# act Apr 15
# " 26
# Thos P. Ray
# for
#
# [3] S
# State of Virginia
# County of Nelson
# On this 3d day of July A.D. One thousand Eight
# hundred and fifty three personally appeared before
# me a Justice of the Peace
# within and for the
# County and State aforesaid Mildred Hart and
# at it 2 or 83 years who being first duly sworn
# according to law, doth on her oath make the following
# declaration in order to obtain the benefit of the provision made
# the act of Congress passed July 7, 1838 an act granting
# half pay and pensions to certain widows"" that she is the
# son of Thomas Ware Deceased who was a soldier in the
# Revolutionary War, and who was inscribed on the Pension
# before his decease and drew a Pension of Twenty Six 1/100
# She further declares that she is still a widow.
# Witness
# Jonathan Cram
# To
# Seth Comm
# Hannah Mark
# Fogy
# Sworn and subscribed on the day and year above written- Before
# Paul Wentworth
# I FURTHER CERTIFY, That the above Declarant is personally known to me
# Paul Winters out of the Peace
# of New Hampshire
# COUNTY, SS.
# Clerk of the Court of Common
# aforesaid, do hereby certify that
# and for said County, duly commissioned and qualified; that his commission was
# day of
# day of
# and the seal of said County, this
# Sold by John F. Brown, No. 1, Ayer's Block, Concord, N. H.
# 184 and will expire
# 18 and that his signature above written
# day of
# 18
# CLERK.
#
# [7] 3
# Kentucky
# Elizabeth Jones
# of Thomas Jones decd
# he was a pensioner under the Act of 1828
# and who died on the 3d October 1833
# Shelby Co. in the State of a
# he was a the of Dr in the company commanded
# Captainof
# the
# commanded
# in for 2 years
# in the Virginia
# Jr
# cribed on the Roll of Ky
# rate of 100 Dollars-
# Cents per annum,
# one on the 4th day of March, 1836
# Certificate of Pension issued the 10th day of Octo
# 1838 and sent Saml
# Load Frankfort Ky.
# Arrears to the 4th of Sept 1838 $250.00
# Semi-annual allowance ending 4 Mar. 39, 50.00
# $300.00
# 1838.
# Recorded by D.D. Addison
# Page 211
# Act July 791
# Book
# Clerk
#
# [8] was in Colebrook, Connecticut, when Zebulon Thompson came home
# from West Point, at which time he read his discharge to Lucy's
# ( also Thankful's) father.
# In order to obtain the date of last payment of pension, name of
# person paid and, possibly, the date of death of this pensioner,
# you should apply to The Comptroller General, General Accounting
# Office, this city, and furnish the following data:
# Lucy Thompson, widow of Zebulon Thompson,
# Certificate #2549
# Issued March 12, 1839
# Rate $80 per annum
# Act of July 4, 1836
# New York Agency.
# Very truly yours,
# A. D. HILLER,
# Executive Assistant
# to the Administrator.
#
# [9] Cortland Village
# the
# Notification sent Nov. 7th 1820 to Joshua Ballard
# (2,759)
# New York Roll
# Jason Crawford
# Private
# 4
# Connecticut line
# in the army of the United States during the Revolutionary War
# Inscribed on the Roll of New York
# at the rate of Eight Dollars per month, to commence on
# the 20 of April 1818
# Certificate of Pension issued the 22 of Sept 1818
# and sent to Ross and Read, Homer
# N. York
# Arrears to 4th of Sept 84 N 15/30
# Semi-anl. all'ce ending 4th March 1819
# 3693
# 48 -
# 3 years 1779
# 1839
# 3
# Continued
# Branley
# Mar
# Virgil Hand
#
# [10] State of Tonopa
# Hawkins County
# on this 17th day of August 1843 Personaly 77
# ---
# me the undersigned one of the parties of the County Court of said
# County Mary England a resident of Scott County in the State of
# Virginia aged Eighty four years who being first duly sworn according
# A
# to law doth on her oath make the following declaration in order to
# obtain the benefit of the provision made by the act of Congress passed
# 4th July 1836 and since them-
# That she is the widow of John
# England late a Pensioner of the United States, on the roll as she has
# been informed laws, at Ridward, Virginia, at the rate of about
# Sixty
# dollars per month, that the said John England was
# private in the war of the Revolution, and for his service she
# refers to his Declaration on file in the war Department
# her said Husband as well as herself not being able to read
# or wite no record was kept of their marriage or of the births
# of the children, and she has therefore no documentary
# Evidence
# to offer
# she further declares that she was
# 1
# married to
# said John England in the month of January day the
# in the year Seventeen hundred and Eighty in Amherst County
# may be entitled under the act of March 3 1855 never
# having received or known herself entitled or made
# application under any pave act of Congress. In evidence
# of her marriage and proof of service of her said husband
# the respectfully refer to the proofs heretofore adduced now
# on file in the pension office and upon which her
# annuity as aforesaid was granted that since being
# placed on the list of Revolutionary Pensioners she has not
# intermarried by still contining the widow of said Daniel Wigham
# Attest, Richard Davis
# Daniel Brigham
# Anna X Bingham
# mark
#
# [14] R
# 1847 heir Bapline.
# Richard Parker
# Strafford in the State of
# who was a
# Son
# by Captain Differ of the Reg commanded
# by Evans
# in the New Hamps
# Militia de
# 29 days
# in the Roll of N H
# of 31 Dollars 55 Cents per annum
# 1883
# 7
# Certificate of Pension issued the 20 day of
# 1835
# April
# Farmington
# and Leut Nastinan
# W
# Arrears to the 4th of ┃
# Semant
# ---
# Vol.
# March 126,20
# attowance ending of
# 15.77
# $141.97
# Revolutionary Claim,
# Act June 7, 1832
# Clerk,
# head
# 5
# Dec 1857
# Let. Hon Jas Farrington
# led 4 1838
# do to N. Eastman Aug. 25, 1845
#
# [15] State of New York
# Sullivan County
# Be it Known that before me James
# Dearns a Justice of the peace in and for the County aforesaid,
# a resident of Mamakating in said County
# personally appeared James Ivory and made oath in due form of
# law, that he enlisted in 1775 in Capt. Hardenburgh Company
# of Infantry as a private Soldier in the second New York Regiment
# commanded by Col. Phillip Van Cortland for the term of nine
# months, and continued to serve the said term, and in the year
# 1776 that he again enlisted in Capt Frenches Company same
# Regiment for three years or during the war, and after the
# agement of the army was in Capt Hamtramick Company
# same regiment, and in the Spring of the year 1781 sent out
# from Fort Schuyler on a scout when he received the wounds for
# which he received the anexed Certificate, and that he is the
# Identile James Ivory to whome the same was given, and
# that he received Sixty dollars a year from the fifteenth day of
# June 1786 to the fourth of April 1816, and from that to the fourth
# of March 1827, he received Eight dollars per month, and that in
# 1818 he was advised to apply for a pension for services under the
# act of Congress of the 18 of March 1818. and from the sixth of
# May 1818 die both pension up to the fourth of March 1827
# at which time he was dropt from the roll of both, and as he
# has been informed no further payment should be made, until
# the amount over deawen was accounted for, which time who
# old expire on or about the first of January 1836--
# He now makes application to be restored on the invalid all
# as his first and just right to a pension so he may receive the
# amount due him from the time the money over drawer was
# accounted for up to the fourth of September next which will afford
# him to relief at the advanced age of 16 years old,
# Sworn and subscribed
# his
# August 22. 1836
# James Hovey
# Mark
# before me James Sevens Justice of the peace

# %%
df_filtered.head()
# Out:
#          NAID                                    naraURL  \
# 4   111769418  https://catalog.archives.gov/id/111769418
# 6   111769418  https://catalog.archives.gov/id/111769418
# 8   111769418  https://catalog.archives.gov/id/111769418
# 15  111769405  https://catalog.archives.gov/id/111769405
# 28  111769387  https://catalog.archives.gov/id/111769387
#
#                                                 title logicalDate  \
# 4   Revolutionary War Pension and Bounty Land Warr...        None
# 6   Revolutionary War Pension and Bounty Land Warr...        None
# 8   Revolutionary War Pension and Bounty Land Warr...        None
# 15  Revolutionary War Pension and Bounty Land Warr...        None
# 28  Revolutionary War Pension and Bounty Land Warr...        None
#
#                                 variantControlNumbers pdfObjectID pdfURL  \
# 4   [{"number": "Fold3 2018", "type": "Search Iden...        None   None
# 6   [{"number": "Fold3 2018", "type": "Search Iden...        None   None
# 8   [{"number": "Fold3 2018", "type": "Search Iden...        None   None
# 15  [{"number": "Fold3 2018", "type": "Search Iden...        None   None
# 28  [{"number": "Fold3 2018", "type": "Search Iden...        None   None
#
#    pageObjectId                                            pageURL  \
# 4     111769420  https://s3.amazonaws.com/NARAprodstorage/lz/mi...
# 6     111769422  https://s3.amazonaws.com/NARAprodstorage/lz/mi...
# 8     111769424  https://s3.amazonaws.com/NARAprodstorage/lz/mi...
# 15    111769407  https://s3.amazonaws.com/NARAprodstorage/lz/mi...
# 28    111769390  https://s3.amazonaws.com/NARAprodstorage/lz/mi...
#
#    pageImageType  ...                                            ocrText  \
# 4    Image (JPG)  ...  1831\nto\nSchaled Tucker\n1941\nMassachusetts\...
# 6    Image (JPG)  ...  ESSEX, ss.\nCommonwealth of Massachusetts.\nAt...
# 8    Image (JPG)  ...  and at the same time he produces to the Court ...
# 15   Image (JPG)  ...  Vermont 18.682\n---\nPeter Woodbury\nof Windso...
# 28   Image (JPG)  ...  Massachusetts 1,25\nMary Woodbury\nwidow of Na...
#
#                ocrUploadDate ocrContributor  \
# 4   2024-11-20T20:32:03.000Z   FamilySearch
# 6   2024-11-20T20:32:03.000Z   FamilySearch
# 8   2024-11-20T20:32:03.000Z   FamilySearch
# 15  2024-11-20T20:32:03.000Z   FamilySearch
# 28  2024-11-20T20:32:02.000Z   FamilySearch
#
#                          transcriptionID  \
# 4                                   None
# 6                                   None
# 8                                   None
# 15  3fc8f1d1-c8be-468a-9d45-6183c4076266
# 28                                  None
#
#                                     transcriptionText  \
# 4                                                None
# 6                                                None
# 8                                                None
# 15  Vermont 18.682\n---\nPeter Woodbury\nof Windso...
# 28                                               None
#
#    transcriptionContributionCount  transcriptionUserNames  \
# 4                             NaN                    None
# 6                             NaN                    None
# 8                             NaN                    None
# 15                            1.0         carlaMSUspartan
# 28                            NaN                    None
#
#       transcriptionDate file_cat  \
# 4                  None  soldier
# 6                  None  soldier
# 8                  None  soldier
# 15  2025-07-27 18:31:59  soldier
# 28                 None    widow
#
#                                         priority_text
# 4   1831\nto\nSchaled Tucker\n1941\nMassachusetts\...
# 6   ESSEX, ss.\nCommonwealth of Massachusetts.\nAt...
# 8   and at the same time he produces to the Court ...
# 15  Vermont 18.682\n---\nPeter Woodbury\nof Windso...
# 28  Massachusetts 1,25\nMary Woodbury\nwidow of Na...
#
# [5 rows x 21 columns]

# %%
df_filtered.columns
# Out:
# Index(['NAID', 'naraURL', 'title', 'logicalDate', 'variantControlNumbers',
#        'pdfObjectID', 'pdfURL', 'pageObjectId', 'pageURL', 'pageImageType',
#        'ocrID', 'ocrText', 'ocrUploadDate', 'ocrContributor',
#        'transcriptionID', 'transcriptionText',
#        'transcriptionContributionCount', 'transcriptionUserNames',
#        'transcriptionDate', 'file_cat', 'priority_text'],
#       dtype='object')

# %%
# Save directly with only the specified columns
cols = ["NAID", "naraURL", "title", "pageObjectId", "pageURL", "file_cat", "priority_text"]
df_filtered[cols].to_parquet('filtered_pension_amounts_subset.parquet', index=False)
